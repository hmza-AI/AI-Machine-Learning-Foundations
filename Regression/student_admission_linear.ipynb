# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("adm_data.csv")
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
x = data[['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research']]
y = data['Chance of Admit ']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 14)
x_train.head()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 247        311          104                  2  2.5   3.5  8.48         0
# 328        324          112                  4  4.0   3.5  8.77         1
# 390        314          102                  2  2.0   2.5  8.24         0
# 170        312          101                  2  2.5   3.5  8.04         1
# 62         304          105                  2  3.0   3.0  8.20         1

# %%
y_train.head()
# Out:
# 247    0.71
# 328    0.80
# 390    0.64
# 170    0.68
# 62     0.54
# Name: Chance of Admit , dtype: float64

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
print(y_test[:5])
print(y_pred[:5])
# Out:
# 85     0.76
# 20     0.64
# 1      0.76
# 346    0.47
# 69     0.78
# Name: Chance of Admit , dtype: float64
# [0.70910181 0.60631877 0.80579274 0.50672174 0.8553925 ]

# %%
mse = mean_squared_error(y_test,y_pred)
print("mean squared error: ",mse)
# Out:
# mean squared error:  0.003315924159652172

# %%
plt.xlabel("True result")
plt.ylabel("Predicted result")
plt.scatter(y_test, y_pred, color = 'green', label = 'Model prediction')
plt.plot(y_test, y_test, color = 'red', label = 'Regression line')
plt.legend()
plt.show()
